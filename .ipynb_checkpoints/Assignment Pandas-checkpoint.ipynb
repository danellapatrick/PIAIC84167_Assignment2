# %% [markdown]
# 1. The first visualization your boss wants you to make is a scatterplot that shows average income in a state vs proportion of women in that state.Open some of the census csv files in the navigator. How are they named? What kind of information do they hold? Will they help us make this graph?

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
# by opening the files named as "state1,state2 or state3 these files shows us the census result with the following columns : 'Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific', 'Income', 'GenderPop'],      dtype='object""
#so we will first concate all the csv files into one frame.

# %%
df1=pd.read_csv("states0.csv")
df1.columns
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income', 'GenderPop'],
#       dtype='object')

# %%
df0=pd.read_csv("states0.csv")
df1=pd.read_csv("states1.csv")
df2=pd.read_csv("states2.csv")
df3=pd.read_csv("states3.csv")
df4=pd.read_csv("states4.csv")
df5=pd.read_csv("states5.csv")
df6=pd.read_csv("states6.csv")
df7=pd.read_csv("states7.csv")
df8=pd.read_csv("states7.csv")
df9=pd.read_csv("states7.csv")
frames=[df0,df1,df2,df3,df4,df5,df6,df7,df8,df9]
df=pd.concat(frames)
df.head(5)
# Out:
#    Unnamed: 0       State  TotalPop             Hispanic                White  \
# 0           0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2           2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3           3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4           4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific              Income            GenderPop
# ...

# %%
df.head() # like this we weill check everyone
# Out:
#    Unnamed: 0       State  TotalPop             Hispanic                White  \
# 0           0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2           2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3           3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4           4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific              Income            GenderPop
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income', 'GenderPop'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0     int64
# State         object
# TotalPop       int64
# Hispanic      object
# White         object
# Black         object
# Native        object
# Asian         object
# Pacific       object
# Income        object
# GenderPop     object
# dtype: object

# %%
#Replacing the dollar sign
dftest=df.Income.str.replace('$','')

# %%
#Converting the data to numeric 
df['Income'] = pd.to_numeric(dftest)
df['Income']
# Out:
# 0    43296.358603
# 1    70354.743902
# 2    54207.820955
# 3    41935.633968
# 4    67264.782303
# 5    64657.801787
# 0    64657.801787
# 1    76146.560588
# 2    61827.976636
# 3    75466.363636
# 4    50690.194987
# 5    50811.082051
# 0    50811.082051
# 1    73264.426282
# 2    48017.315436
# 3    59587.048875
# 4    48616.227848
# 5    53017.753041
# 0    53017.753041
# 1    53885.612648
# 2    45285.802536
# 3    44957.993761
# 4    49181.974359
# 5    78765.400725
# 0    78765.400725
# 1    72838.936726
# 2    51201.830037
# 3    62820.833959
# 4    38909.919207
# 5    49763.987726
# 0    49763.987726
# 1    47645.682836
# 2    55916.469697
# 3    55526.525074
# 4    68728.859589
# 5    76581.083417
# 0    76581.083417
# 1    47329.967871
# 2    64290.749113
# 3    49937.464137
# 4    58188.112195
# 5    49655.248466
# 0    49655.248466
# 1    48100.854267
# 2    54271.901818
# 3    56170.464510
# 4    20720.538286
# 5    59125.270833
# 0    49655.248466
# 1    48100.854267
# ...

# %%
df
# Out:
#    Unnamed: 0                 State  TotalPop             Hispanic  \
# 0           0               Alabama   4830620  3.7516156462584975%
# 1           1                Alaska    733375   5.909580838323351%
# 2           2               Arizona   6641928  29.565921052631502%
# 3           3              Arkansas   2958208   6.215474452554738%
# 4           4            California  38421464  37.291874687968054%
# 5           5              Colorado   5278906   20.78438003220608%
# 0           0              Colorado   5278906   20.78438003220608%
# 1           1           Connecticut   3593222  15.604830917874388%
# 2           2              Delaware    926454    8.82476635514019%
# 3           3  District of Columbia    647484   9.165921787709499%
# 4           4               Florida  19645772    21.3385426653884%
# 5           5               Georgia  10006693   8.418242207460397%
# 0           0               Georgia  10006693   8.418242207460397%
# ...

# %%
df['GenderPop']
# Out:
# 0      2341093M_2489527F
# 1        384160M_349215F
# 2      3299088M_3342840F
# 3      1451913M_1506295F
# 4    19087135M_19334329F
# 5      2648667M_2630239F
# 0      2648667M_2630239F
# 1      1751607M_1841615F
# 2        448413M_478041F
# 3        306674M_340810F
# 4     9600009M_10045763F
# 5      4883331M_5123362F
# 0      4883331M_5123362F
# 1        709871M_696428F
# 2        810464M_806083F
# 3      6316899M_6556862F
# 4      3235263M_3333382F
# 5      1534595M_1558931F
# 0      1534595M_1558931F
# 1      1439862M_1453125F
# 2      2164208M_2233145F
# 3      2261156M_2364097F
# 4        650081M_679019F
# 5             2872643M_F
# 0             2872643M_F
# 1      3249650M_3455936F
# 2      4861973M_5038598F
# 3      2692166M_2727005F
# 4      1451723M_1536358F
# 5      2964003M_3081445F
# 0      2964003M_3081445F
# 1              510163M_F
# 2        929606M_939759F
# 3      1407735M_1390901F
# 4        653484M_670717F
# 5      4343027M_4561386F
# 0      4343027M_4561386F
# ...

# %%
# Now Converting the Gender Pop into Female only 
dfg=df['GenderPop']
#dfg[dfg.str.match(r'(^P.*)')==True]
#s = pd.Series(["StatueofLiberty built-on 28-Oct-1886"])
dfgf=dfg.str.split(r"_", n=-1,expand=True)
#dfgf.rename(columns={'0':'MalePop', '1':'FemalePop'}, inplace=False)
dfgf[1]
# Out:
# 0     2489527F
# 1      349215F
# 2     3342840F
# 3     1506295F
# 4    19334329F
# 5     2630239F
# 0     2630239F
# 1     1841615F
# 2      478041F
# 3      340810F
# 4    10045763F
# 5     5123362F
# 0     5123362F
# 1      696428F
# 2      806083F
# 3     6556862F
# 4     3333382F
# 5     1558931F
# 0     1558931F
# 1     1453125F
# 2     2233145F
# 3     2364097F
# 4      679019F
# 5            F
# 0            F
# 1     3455936F
# 2     5038598F
# 3     2727005F
# 4     1536358F
# 5     3081445F
# 0     3081445F
# 1            F
# 2      939759F
# 3     1390901F
# 4      670717F
# 5     4561386F
# 0     4561386F
# 1     1051703F
# 2    10131373F
# 3     5049925F
# 4      353677F
# 5     5913084F
# 0     5913084F
# 1     1942789F
# 2     1990780F
# 3     6534215F
# 4     1869213F
# 5      543273F
# 0     5913084F
# 1     1942789F
# 2     1990780F
# 3     6534215F
# 4     1869213F
# 5      543273F
# 0     5913084F
# 1     1942789F
# 2     1990780F
# 3     6534215F
# ...

# %%
df['Female'] = dfgf[1]
df
# Out:
#    Unnamed: 0                 State  TotalPop             Hispanic  \
# 0           0               Alabama   4830620  3.7516156462584975%
# 1           1                Alaska    733375   5.909580838323351%
# 2           2               Arizona   6641928  29.565921052631502%
# 3           3              Arkansas   2958208   6.215474452554738%
# 4           4            California  38421464  37.291874687968054%
# 5           5              Colorado   5278906   20.78438003220608%
# 0           0              Colorado   5278906   20.78438003220608%
# 1           1           Connecticut   3593222  15.604830917874388%
# 2           2              Delaware    926454    8.82476635514019%
# 3           3  District of Columbia    647484   9.165921787709499%
# 4           4               Florida  19645772    21.3385426653884%
# 5           5               Georgia  10006693   8.418242207460397%
# 0           0               Georgia  10006693   8.418242207460397%
# ...

# %%
df[df.columns[9:11]] 
#df.drop(columns=['GenderPop'], inplace=True)
# Out:
#          Income            GenderPop
# 0  43296.358603    2341093M_2489527F
# 1  70354.743902      384160M_349215F
# 2  54207.820955    3299088M_3342840F
# 3  41935.633968    1451913M_1506295F
# 4  67264.782303  19087135M_19334329F
# 5  64657.801787    2648667M_2630239F
# 0  64657.801787    2648667M_2630239F
# 1  76146.560588    1751607M_1841615F
# 2  61827.976636      448413M_478041F
# 3  75466.363636      306674M_340810F
# 4  50690.194987   9600009M_10045763F
# 5  50811.082051    4883331M_5123362F
# 0  50811.082051    4883331M_5123362F
# 1  73264.426282      709871M_696428F
# 2  48017.315436      810464M_806083F
# 3  59587.048875    6316899M_6556862F
# 4  48616.227848    3235263M_3333382F
# 5  53017.753041    1534595M_1558931F
# 0  53017.753041    1534595M_1558931F
# 1  53885.612648    1439862M_1453125F
# 2  45285.802536    2164208M_2233145F
# 3  44957.993761    2261156M_2364097F
# 4  49181.974359      650081M_679019F
# 5  78765.400725           2872643M_F
# ...

# %%
# now we will remove F from the Female Column 
dffemale=df.Female.str.replace('F','')
df['Female'] = pd.to_numeric(dffemale)
df['Female']
# Out:
# 0     2489527.0
# 1      349215.0
# 2     3342840.0
# 3     1506295.0
# 4    19334329.0
# 5     2630239.0
# 0     2630239.0
# 1     1841615.0
# 2      478041.0
# 3      340810.0
# 4    10045763.0
# 5     5123362.0
# 0     5123362.0
# 1      696428.0
# 2      806083.0
# 3     6556862.0
# 4     3333382.0
# 5     1558931.0
# 0     1558931.0
# 1     1453125.0
# 2     2233145.0
# 3     2364097.0
# 4      679019.0
# 5           NaN
# 0           NaN
# 1     3455936.0
# 2     5038598.0
# 3     2727005.0
# 4     1536358.0
# 5     3081445.0
# 0     3081445.0
# 1           NaN
# 2      939759.0
# 3     1390901.0
# 4      670717.0
# 5     4561386.0
# 0     4561386.0
# 1     1051703.0
# 2    10131373.0
# 3     5049925.0
# 4      353677.0
# 5     5913084.0
# 0     5913084.0
# 1     1942789.0
# 2     1990780.0
# 3     6534215.0
# 4     1869213.0
# 5      543273.0
# 0     5913084.0
# 1     1942789.0
# 2     1990780.0
# 3     6534215.0
# 4     1869213.0
# 5      543273.0
# 0     5913084.0
# ...

# %%
df[df.columns[9:12]]
# Out:
#          Income            GenderPop      Female
# 0  43296.358603    2341093M_2489527F   2489527.0
# 1  70354.743902      384160M_349215F    349215.0
# 2  54207.820955    3299088M_3342840F   3342840.0
# 3  41935.633968    1451913M_1506295F   1506295.0
# 4  67264.782303  19087135M_19334329F  19334329.0
# 5  64657.801787    2648667M_2630239F   2630239.0
# 0  64657.801787    2648667M_2630239F   2630239.0
# 1  76146.560588    1751607M_1841615F   1841615.0
# 2  61827.976636      448413M_478041F    478041.0
# 3  75466.363636      306674M_340810F    340810.0
# 4  50690.194987   9600009M_10045763F  10045763.0
# 5  50811.082051    4883331M_5123362F   5123362.0
# 0  50811.082051    4883331M_5123362F   5123362.0
# 1  73264.426282      709871M_696428F    696428.0
# 2  48017.315436      810464M_806083F    806083.0
# 3  59587.048875    6316899M_6556862F   6556862.0
# 4  48616.227848    3235263M_3333382F   3333382.0
# 5  53017.753041    1534595M_1558931F   1558931.0
# ...

# %%
# Filling the Nan Values 
df.fillna(0, inplace=True)
df[df.columns[9:12]] 
df
# Out:
#    Unnamed: 0                 State  TotalPop             Hispanic  \
# 0           0               Alabama   4830620  3.7516156462584975%
# 1           1                Alaska    733375   5.909580838323351%
# 2           2               Arizona   6641928  29.565921052631502%
# 3           3              Arkansas   2958208   6.215474452554738%
# 4           4            California  38421464  37.291874687968054%
# 5           5              Colorado   5278906   20.78438003220608%
# 0           0              Colorado   5278906   20.78438003220608%
# 1           1           Connecticut   3593222  15.604830917874388%
# 2           2              Delaware    926454    8.82476635514019%
# 3           3  District of Columbia    647484   9.165921787709499%
# 4           4               Florida  19645772    21.3385426653884%
# 5           5               Georgia  10006693   8.418242207460397%
# 0           0               Georgia  10006693   8.418242207460397%
# ...

# %%
x=df['Income']
y=df['Female']
plt.figure(figsize=(10, 5))
plt.scatter(x, y)
plt.title("scatter plot of the Complete states files   ")
plt.ylabel('Income' )
plt.xlabel(' Female Propotion' )
# Out:
# Text(0.5, 0, ' Female Propotion')

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#    Unnamed: 0                 State  TotalPop             Hispanic  \
# 0           0               Alabama   4830620  3.7516156462584975%
# 1           1                Alaska    733375   5.909580838323351%
# 2           2               Arizona   6641928  29.565921052631502%
# 3           3              Arkansas   2958208   6.215474452554738%
# 4           4            California  38421464  37.291874687968054%
# 5           5              Colorado   5278906   20.78438003220608%
# 0           0              Colorado   5278906   20.78438003220608%
# 1           1           Connecticut   3593222  15.604830917874388%
# 2           2              Delaware    926454    8.82476635514019%
# 3           3  District of Columbia    647484   9.165921787709499%
# 4           4               Florida  19645772    21.3385426653884%
# 5           5               Georgia  10006693   8.418242207460397%
# 0           0               Georgia  10006693   8.418242207460397%
# ...

# %%
x=df['Income']
y=df['Female']
plt.figure(figsize=(10, 5))
plt.scatter(x, y,c='coral')
plt.title("scatter plot of the Complete states files   ")
plt.ylabel('Income' )
plt.xlabel(' Female Propotion' )
# Out:
# Text(0.5, 0, ' Female Propotion')

# %% [markdown]
# # histogram

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income', 'GenderPop', 'Female'],
#       dtype='object')

# %%
#Removing the Percentage sign 
#df.Female.str.replace('F','')
df['Asian'] = pd.to_numeric(df.Asian.str.replace('%',''))
df['Pacific'] = pd.to_numeric(df.Pacific.str.replace('%',''))
df['Hispanic'] = pd.to_numeric(df.Hispanic.str.replace('%',''))
df['White'] = pd.to_numeric(df.White.str.replace('%',''))
df['Black'] = pd.to_numeric(df.Black.str.replace('%',''))
df['Native'] = pd.to_numeric(df.Native.str.replace('%',''))

# %%
df.fillna(0, inplace=True)

# %%
df[df.columns[3:9]]
# Out:
#     Hispanic      White      Black     Native      Asian   Pacific
# 0   3.751616  61.878656  31.252976   0.453231   1.050255  0.034354
# 1   5.909581  60.910180   2.848503  16.391018   5.450299  1.058683
# 2  29.565921  57.120000   3.850987   4.355066   2.876579  0.167632
# 3   6.215474  71.137810  18.968759   0.522920   1.142336  0.146861
# 4  37.291875  40.215789   5.677396   0.405292  13.052234  0.351410
# 5  20.784380  69.895572   3.546377   0.573833   2.661997  0.000000
# 0  20.784380  69.895572   3.546377   0.573833   2.661997  0.000000
# 1  15.604831  67.677053  10.348068   0.126208   4.021981  0.018599
# 2   8.824766  64.632710  20.743925   0.259813   3.268692  0.000000
# 3   9.165922  33.103911  51.776536   0.200559   3.383240  0.029609
# 4  21.338543  59.083749  15.165676   0.210451   2.283174  0.051510
# 5   8.418242  54.286306  32.088298   0.187583   3.097649  0.046602
# 0   8.418242  54.286306  32.088298   0.187583   3.097649  0.046602
# ...

# %%
s1=df['Asian']
s2=df['Hispanic']
s3=df['Black']
s4=df['White']
s5=df['Native']
s6=df['Pacific']
a = [s1,s2,s3,s4,s5,s6]
  
# Creating histogram 
fig, ax = plt.subplots(figsize =(10, 7)) 
ax.hist(a, bins =2) 
  
# Show plot 
plt.show()

# %%
import pandas as pd

df_hist = {'Asian': s1," Hispanic":s2,"Black":s3,"White":s4,"Native":s5,"Pacific":s6 }

df_hist = pd.DataFrame(df_hist, columns = ["Asian","Hispanic","Black","White","Native","Pacific"])

df_hist['Hispanic']=df["Hispanic"]
df_hist
# Out:
#        Asian   Hispanic      Black      White     Native   Pacific
# 0   1.050255   3.751616  31.252976  61.878656   0.453231  0.034354
# 1   5.450299   5.909581   2.848503  60.910180  16.391018  1.058683
# 2   2.876579  29.565921   3.850987  57.120000   4.355066  0.167632
# 3   1.142336   6.215474  18.968759  71.137810   0.522920  0.146861
# 4  13.052234  37.291875   5.677396  40.215789   0.405292  0.351410
# 5   2.661997  20.784380   3.546377  69.895572   0.573833  0.000000
# 0   2.661997  20.784380   3.546377  69.895572   0.573833  0.000000
# 1   4.021981  15.604831  10.348068  67.677053   0.126208  0.018599
# 2   3.268692   8.824766  20.743925  64.632710   0.259813  0.000000
# 3   3.383240   9.165922  51.776536  33.103911   0.200559  0.029609
# 4   2.283174  21.338543  15.165676  59.083749   0.210451  0.051510
# 5   3.097649   8.418242  32.088298  54.286306   0.187583  0.046602
# 0   3.097649   8.418242  32.088298  54.286306   0.187583  0.046602
# ...

# %%
df_hist.hist(figsize=(10, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D537D7B408>,
# ...
#       dtype=object)

# %%
df_hist.plot.hist(bins=25)

# %%
df_hist.plot.hist(bins=20, alpha=0.7)

# %%
# Import libraries 
from matplotlib import pyplot as plt 
import numpy as np 


# Creating dataset 
cars = ["Asian","Hispanic","Black","White","Native","Pacific"] 
s1=np.mean(s1)
s2=np.mean(df_hist['Hispanic'])
s3=np.mean(s3)
s4=np.mean(s4)
s5=np.mean(s5)
s6=np.mean(s6)

#df_hist.series.apply(pd.to_numeric)

data = [s1,s2,s3,s4,s5,s6] 

# Creating plot 
fig = plt.figure(figsize =(10, 7)) 
plt.pie(data, labels = cars) 

# show plot 
plt.show()

# %%
df_hist.astype(int)
# Out:
#    Asian  Hispanic  Black  White  Native  Pacific
# 0      1         3     31     61       0        0
# 1      5         5      2     60      16        1
# 2      2        29      3     57       4        0
# 3      1         6     18     71       0        0
# 4     13        37      5     40       0        0
# 5      2        20      3     69       0        0
# 0      2        20      3     69       0        0
# 1      4        15     10     67       0        0
# 2      3         8     20     64       0        0
# 3      3         9     51     33       0        0
# 4      2        21     15     59       0        0
# 5      3         8     32     54       0        0
# 0      3         8     32     54       0        0
# 1     36         9      2     25       0        8
# 2      1        11      0     83       1        0
# 3      4        15     17     60       0        0
# 4      1         6     11     78       0        0
# 5      1         5      3     87       0        0
# ...

# %% [markdown]
# Part #2

# %%
df_inventory=pd.read_csv("Inventory.csv")

# %%
df_inventory.head(10)
# Out:
#         location  product_type         product_description  quantity  price
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99

# %%
#The first 10 rows represent data from your Staten Island location. Select these rows and save them to staten_island.
staten_island= df_inventory.loc[(df_inventory['location'] == 'Staten Island') ]
staten_island
# Out:
#         location  product_type         product_description  quantity  price
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99

# %%
#A customer just emailed you asking what products are sold at your Staten Island location. Select the column product_description from staten_island and save it to the variable product_request.

product_request=staten_island['product_description']

# %%
#5.Another customer emails to ask what types of seeds are sold at the Brooklyn location. Select all rows where location is equal to Brooklyn and product_type is equal to seeds and save them to the variable seed_request
brook_island= df_inventory.loc[(df_inventory['location'] == 'Brooklyn') ]
seed_request=brook_island.loc[(brook_island['product_type'] == 'seeds') ]

# %%
#Add a column to inventory called in_stock which is True if quantity is greater than 0 and False if quantity equals 0.
df_inventory['in_stock']=df_inventory['quantity']>0
df_inventory
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
#Create a column called total_value that is equal to price multiplied by quantity
df_inventory['total_values']=df_inventory['price']*df_inventory['quantity']
df_inventory
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
product_type=df_inventory['product_type']
product_description=df_inventory['product_description']

# %%
combine_lambda=product_type +' '+ product_description
df_inventory['full_description']=combine_lambda

# %%
df_inventory
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...
